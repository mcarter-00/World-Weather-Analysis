# %%
# Import dependencies
import pandas as pd
import gmaps
import requests

from config import g_key

# %%
# Open File
weather_data_df = pd.read_csv("challenge_data/WeatherPy_challenge.csv")
weather_data_df.head(10)
# Out:
#    City_ID         City Country                 Date    Lat     Lng  Max Temp  \
# 0        0     Khatanga      RU  2020-02-23 09:52:15  71.97  102.50     15.30
# 1        1   Sao Filipe      CV  2020-02-23 09:52:15  14.90  -24.50     68.47
# 2        2       Albany      US  2020-02-23 09:52:15  42.60  -73.97     28.00
# 3        3    Bahir Dar      ET  2020-02-23 09:52:15  11.59   37.39     84.18
# 4        4   Butaritari      KI  2020-02-23 09:52:16   3.07  172.79     84.76
# 5        5      Milkovo      RU  2020-02-23 09:52:16  54.72  158.62     -3.01
# 6        6      Ambanja      MG  2020-02-23 09:52:16 -13.68   48.45     89.60
# 7        7       Matara      LK  2020-02-23 09:47:47   5.95   80.54     88.52
# 8        8  Provideniya      RU  2020-02-23 09:52:16  64.38 -173.30     -9.81
# 9        9         Hilo      US  2020-02-23 09:52:17  19.73 -155.09     68.00
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        85         100       13.31     overcast clouds
# 1        80         100       17.36     overcast clouds
# 2        73           1        4.47           clear sky
# 3        19           0        8.25           clear sky
# 4        77          76       14.70          light rain
# 5        84           3        2.93           clear sky
# 6        70          75        2.24       broken clouds
# 7        59          69        9.66          light rain
# 8       100          53        2.95       broken clouds
# 9        77          75        3.36       broken clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                      5.00                      0.13
# 1                      5.00                      0.13
# 2                      5.00                      0.13
# 3                      5.00                      0.13
# 4                      2.88                      0.13
# 5                      2.88                      0.13
# 6                      2.88                      0.13
# 7                      0.19                      0.13
# 8                      0.19                      0.13
# 9                      0.19                      0.13

# %%
# Ask the customer to add a minimum and maximum temperature value
min_temp = float(input("What is your minimum temperature preference? "))
max_temp = float(input("What is your maximum temperature preference? "))

# Ask the customer if they would like it to be raining or not
want_rain = str(input("Do you want it to be raining? (yes/no) "))
# Ask the customer if they would like it to be snowing or not
want_snow = str(input("Do you want it to be snowing? (yes/no) "))
# Out:
# What is your minimum temperature preference? 60
# What is your maximum temperature preference? 80
# Do you want it to be raining? (yes/no) no
# Do you want it to be snowing? (yes/no) no

# %%
# Filter the dataset to find the cities that fit the criteria
preferred_cities_df = weather_data_df.loc[(weather_data_df["Max Temp"] <= max_temp) & 
                                          (weather_data_df["Max Temp"] >= min_temp)]

preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date    Lat     Lng  \
# 1         1      Sao Filipe      CV  2020-02-23 09:52:15  14.90  -24.50
# 9         9            Hilo      US  2020-02-23 09:52:17  19.73 -155.09
# 10       10           Vaini      TO  2020-02-23 09:52:17 -21.20 -175.20
# 25       25         Rikitea      PF  2020-02-23 09:52:20 -23.12 -134.97
# 26       26           Kapaa      US  2020-02-23 09:52:20  22.08 -159.32
# 27       27         Lanquin      GT  2020-02-23 09:52:21  15.57  -89.97
# 31       31          Hobart      AU  2020-02-23 09:52:21 -42.88  147.33
# 33       33  Port Elizabeth      ZA  2020-02-23 09:52:22 -33.92   25.57
# 39       39      Walvis Bay     NaN  2020-02-23 09:52:23 -22.96   14.51
# 46       46        Flinders      AU  2020-02-23 09:52:24 -34.58  150.86
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 1      68.47        80         100       17.36     overcast clouds
# 9      68.00        77          75        3.36       broken clouds
# 10     78.80        94          75       10.29       broken clouds
# 25     79.11        66           0        3.83           clear sky
# 26     73.40        88          20       11.41          few clouds
# 27     60.22        99          98        1.97          light rain
# 31     62.60        59          75       13.87       broken clouds
# 33     71.60        46          40       11.41    scattered clouds
# 39     69.80        68          47       13.87    scattered clouds
# 46     72.00        77         100        9.17     overcast clouds
#
#     Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 1                       5.00                      0.13
# 9                       0.19                      0.13
# 10                      0.19                      0.13
# 25                      0.94                      0.13
# 26                      0.94                      0.13
# 27                      0.50                      0.94
# 31                      0.50                      0.94
# 33                      0.50                      0.94
# 39                      0.38                      0.94
# 46                      0.38                      0.94

# %%
# Create a DataFrame called hotel_df to store hotel names along with 
# city, country, max temp, current weather description, latitude, longitude 
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 1       Sao Filipe      CV     68.47     overcast clouds  14.90  -24.50
# 9             Hilo      US     68.00       broken clouds  19.73 -155.09
# 10           Vaini      TO     78.80       broken clouds -21.20 -175.20
# 25         Rikitea      PF     79.11           clear sky -23.12 -134.97
# 26           Kapaa      US     73.40          few clouds  22.08 -159.32
# 27         Lanquin      GT     60.22          light rain  15.57  -89.97
# 31          Hobart      AU     62.60       broken clouds -42.88  147.33
# 33  Port Elizabeth      ZA     71.60    scattered clouds -33.92   25.57
# 39      Walvis Bay     NaN     69.80    scattered clouds -22.96   14.51
# 46        Flinders      AU     72.00     overcast clouds -34.58  150.86
#
#    Hotel Name
# 1
# 9
# 10
# 25
# 26
# 27
# 31
# 33
# 39
# 46

# %%
# Configure gmaps to use my Google API Key
gmaps.configure(api_key=g_key)

# %%
# Set the parameters for a hotel
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterature through the Hotel DataFrame
for index, row in hotel_df.iterrows():
    
    # Get the latitude and longitude
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary
    params["location"] = f"{lat}, {lng}"
    
    # Use the search term "lodging" and our latitude and longitude
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # Make request and get the JSON data from the search
    hotels = requests.get(base_url, params=params).json()
    
    # Grab the first hotel from the results and store it
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found. Skipping...")
# Out:
# Hotel not found. Skipping...
# Hotel not found. Skipping...
# Hotel not found. Skipping...
# Hotel not found. Skipping...
# Hotel not found. Skipping...
# Hotel not found. Skipping...
# Hotel not found. Skipping...
# Hotel not found. Skipping...

# %%
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 1       Sao Filipe      CV     68.47     overcast clouds  14.90  -24.50
# 9             Hilo      US     68.00       broken clouds  19.73 -155.09
# 10           Vaini      TO     78.80       broken clouds -21.20 -175.20
# 25         Rikitea      PF     79.11           clear sky -23.12 -134.97
# 26           Kapaa      US     73.40          few clouds  22.08 -159.32
# 27         Lanquin      GT     60.22          light rain  15.57  -89.97
# 31          Hobart      AU     62.60       broken clouds -42.88  147.33
# 33  Port Elizabeth      ZA     71.60    scattered clouds -33.92   25.57
# 39      Walvis Bay     NaN     69.80    scattered clouds -22.96   14.51
# 46        Flinders      AU     72.00     overcast clouds -34.58  150.86
#
#                                  Hotel Name
# 1                               Tortuga B&B
# 9                       Hilo Hawaiian Hotel
# 10                      Keleti Beach Resort
# 25                           Pension Maro'i
# 26   Sheraton Kauai Resort at Coconut Beach
# 27                       Yaxlik River Lodge
# 31                       St Ives Apartments
# 33                   39 On Nile Guest House
# 39                    Oyster Box Guesthouse
# 46  Shellharbour Resort & Conference Centre

# %%
# Create the output file (CSV)
output_data_file = "challenge_data/WeatherPy_vacation.csv"

# Export the hotel DataFrame into a CSV file
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Description Definition
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} 'F</dd>
</dl>
"""

# Store the DataFrame Row
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add marker layer map
locations = hotel_df[["Lat", "Lng"]]

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

#fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
